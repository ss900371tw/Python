# %%
import os
print('Current dir:',os.getcwd())
count=0
for item in os.listdir():
    count+=1
    print(count,item)
print('Total',count,'items in',os.getcwd())
# Out:
# Current dir: C:\Users\user\Desktop\Python\Python基礎與物件導向概念介紹
# 1 .ipynb_checkpoints
# 2 ch01.ipynb
# 3 ch01pub.pdf
# 4 ch02.ipynb
# 5 ch02pub.pdf
# 6 ch03.ipynb
# 7 ch03pub.pdf
# 8 ch04.ipynb
# 9 ch04pub.pdf
# 10 ch05.ipynb
# 11 ch05pub.pdf
# 12 ch06.ipynb
# 13 ch06pub.pdf
# 14 RnJ.txt
# Total 14 items in C:\Users\user\Desktop\Python\Python基礎與物件導向概念介紹

# %%
import os
path='C:/Users/user/Desktop/Python/'

for item in os.walk(path):
    print('dir name:', item[0])
    print('sub-dir list:', item[1])
    print('file list:', item[2])
    print('='*80)
# Out:
# dir name: C:/Users/user/Desktop/Python/
# sub-dir list: ['AI人工智慧程式設計', 'Python基礎與物件導向概念介紹', 'Python網路爬蟲技術與金融資訊擷取', '金融大數據分析']
# file list: []
# ...
# dir name: C:/Users/user/Desktop/Python/AI人工智慧程式設計
# sub-dir list: []
# file list: ['car.data', 'ch01pub.pdf', 'ch02.ipynb', 'ch02pub.pdf', 'ch03-2.ipynb', 'ch03.ipynb', 'ch03pub.pdf', 'ch04-2.ipynb', 'ch04.ipynb', 'ch04pub.pdf', 'ch05-2.ipynb', 'ch05-3.ipynb', 'ch05-4.ipynb', 'ch05-5.ipynb', 'ch05.ipynb', 'ch05pub.pdf', 'iris.data']
# ...
# dir name: C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹
# sub-dir list: ['.ipynb_checkpoints']
# file list: ['ch01.ipynb', 'ch01pub.pdf', 'ch02.ipynb', 'ch02pub.pdf', 'ch03.ipynb', 'ch03pub.pdf', 'ch04.ipynb', 'ch04pub.pdf', 'ch05.ipynb', 'ch05pub.pdf', 'ch06.ipynb', 'ch06pub.pdf', 'RnJ.txt']
# ...
# dir name: C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹\.ipynb_checkpoints
# sub-dir list: []
# file list: ['ch06-checkpoint.ipynb']
# ...
# dir name: C:/Users/user/Desktop/Python/Python網路爬蟲技術與金融資訊擷取
# sub-dir list: []
# ...

# %%
import os
path='C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/'
subdir='.ipynb_checkpoints'
path2=os.path.join(path,subdir)
print(path2)
print('real folder',os.path.isdir(path2))
print('exist?',os.path.exists(path2))

subdir='nono'
path3=os.path.join(path,subdir)
print(path2)
print('real folder',os.path.isdir(path3))
print('exist?',os.path.exists(path3))
# Out:
# C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/.ipynb_checkpoints
# real folder True
# exist? True
# C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/.ipynb_checkpoints
# real folder False
# exist? False

# %%
import os
subdir1='C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub1'
subdir2='C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub2/sub3'
os.mkdir(subdir1)
os.makedirs(subdir2)

# %%
import os
subdir1='C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub1'
subdir2='C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub4'
os.rename(subdir1,subdir2)

# %%
import os
from datetime import datetime
path='C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/'
print(list(os.walk(path)))
# Out:
# [('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/', ['.ipynb_checkpoints', 'sub2', 'sub4'], ['ch01.ipynb', 'ch01pub.pdf', 'ch02.ipynb', 'ch02pub.pdf', 'ch03.ipynb', 'ch03pub.pdf', 'ch04.ipynb', 'ch04pub.pdf', 'ch05.ipynb', 'ch05pub.pdf', 'ch06.ipynb', 'ch06pub.pdf', 'RnJ.txt']), ('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/.ipynb_checkpoints', [], ['ch06-checkpoint.ipynb']), ('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub2', ['sub3'], []), ('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub2\\sub3', [], []), ('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub4', [], [])]

# %%
for entry in os.scandir(path):
    info=entry.stat()
    da=datetime.utcfromtimestamp(info.st_mtime)
    dstr=da.strftime('%Y/%m/%d')
    if entry.is_dir():
        print('資料夾:',entry.name,'最後存取時間:',dstr)
    elif entry.is_file():
        print('檔案:',entry.name,'最後存取時間:',dstr)
# Out:
# 資料夾: .ipynb_checkpoints 最後存取時間: 2021/10/03
# 檔案: ch01.ipynb 最後存取時間: 2021/10/03
# 檔案: ch01pub.pdf 最後存取時間: 2021/10/03
# 檔案: ch02.ipynb 最後存取時間: 2021/10/03
# 檔案: ch02pub.pdf 最後存取時間: 2021/10/03
# 檔案: ch03.ipynb 最後存取時間: 2021/10/03
# 檔案: ch03pub.pdf 最後存取時間: 2021/10/03
# 檔案: ch04.ipynb 最後存取時間: 2021/10/03
# 檔案: ch04pub.pdf 最後存取時間: 2021/10/03
# 檔案: ch05.ipynb 最後存取時間: 2021/10/03
# 檔案: ch05pub.pdf 最後存取時間: 2021/10/03
# 檔案: ch06.ipynb 最後存取時間: 2021/10/03
# 檔案: ch06pub.pdf 最後存取時間: 2021/10/03
# 檔案: RnJ.txt 最後存取時間: 2021/10/03
# 資料夾: sub2 最後存取時間: 2021/10/03
# 資料夾: sub4 最後存取時間: 2021/10/03

# %%
for entry in os.scandir(path):
    info=entry.stat()
    da=datetime.utcfromtimestamp(info.st_mtime)
    dstr=da.strftime('%Y/%m/%d')
    if entry.is_dir():
        print(entry.name,'File folder',dstr)
    elif entry.is_file():
        ffname=os.path.join(path,entry.name)
        fsize=int(os.path.getsize(ffname)/1024)
        ext=os.path.splitext(ffname)[-1].replace('.','')
        print(entry.name+'\t\t\t',str(fsize)+'KB',ext,dstr)
# Out:
# .ipynb_checkpoints File folder 2021/10/03
# ch01.ipynb			 1KB ipynb 2021/10/03
# ch01pub.pdf			 2173KB pdf 2021/10/03
# ch02.ipynb			 16KB ipynb 2021/10/03
# ch02pub.pdf			 1931KB pdf 2021/10/03
# ch03.ipynb			 25KB ipynb 2021/10/03
# ch03pub.pdf			 2890KB pdf 2021/10/03
# ch04.ipynb			 21KB ipynb 2021/10/03
# ch04pub.pdf			 2296KB pdf 2021/10/03
# ch05.ipynb			 10KB ipynb 2021/10/03
# ch05pub.pdf			 1581KB pdf 2021/10/03
# ch06.ipynb			 21KB ipynb 2021/10/03
# ch06pub.pdf			 2352KB pdf 2021/10/03
# RnJ.txt			 149KB txt 2021/10/03
# sub2 File folder 2021/10/03
# sub4 File folder 2021/10/03

# %%
os.rmdir('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub4')
os.rmdir('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub2/sub3')
os.rmdir('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/sub2')

# %%
os.remove('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/.ipynb_checkpoints/ch06-checkpoint.ipynb')

# %%
os.rmdir('C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/.ipynb_checkpoints')

# %%
infname = 'RnJ.txt'
infile = open(infname, 'rt')

for line in infile:
    print(line, end='')

infile.close()
# Out:
# Romeo and Juliet
#
# ACT I
# PROLOGUE
#
#     Two households, both alike in dignity,
#     In fair Verona, where we lay our scene,
#     From ancient grudge break to new mutiny,
#     Where civil blood makes civil hands unclean.
#     From forth the fatal loins of these two foes
#     A pair of star-cross'd lovers take their life;
#     Whose misadventured piteous overthrows
#     Do with their death bury their parents' strife.
#     The fearful passage of their death-mark'd love,
#     And the continuance of their parents' rage,
#     Which, but their children's end, nought could remove,
#     Is now the two hours' traffic of our stage;
#     The which if you with patient ears attend,
#     What here shall miss, our toil shall strive to mend.
#
# SCENE I. Verona. A public place.
#
#     Enter SAMPSON and GREGORY, of the house of Capulet, armed with swords and bucklers
#
# SAMPSON
#
#     Gregory, o' my word, we'll not carry coals.
#
# GREGORY
#
# ...

# %%
infname = 'C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/RnJ.txt'
infile = open(infname, 'rt')
outfname = 'C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/RnJ.out'
outfile = open(outfname, 'wt')

for line in infile:
    str1 = line.strip()
    if len(str1)>0:
        print(str1) 
        outfile.write(str1+'\n')
infile.close()
outfile.close()
# Out:
# Romeo and Juliet
# ACT I
# PROLOGUE
# Two households, both alike in dignity,
# In fair Verona, where we lay our scene,
# From ancient grudge break to new mutiny,
# Where civil blood makes civil hands unclean.
# From forth the fatal loins of these two foes
# A pair of star-cross'd lovers take their life;
# Whose misadventured piteous overthrows
# Do with their death bury their parents' strife.
# The fearful passage of their death-mark'd love,
# And the continuance of their parents' rage,
# Which, but their children's end, nought could remove,
# Is now the two hours' traffic of our stage;
# The which if you with patient ears attend,
# What here shall miss, our toil shall strive to mend.
# SCENE I. Verona. A public place.
# Enter SAMPSON and GREGORY, of the house of Capulet, armed with swords and bucklers
# SAMPSON
# Gregory, o' my word, we'll not carry coals.
# GREGORY
# No, for then we should be colliers.
# SAMPSON
# I mean, an we be in choler, we'll draw.
# GREGORY
# ...

# %%
infname = 'C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/RnJ.txt'
inf=open(infname,'r')
line=inf.readline()
while line:
    print(line,end='')
    line=inf.readline()
# Out:
# Romeo and Juliet
#
# ACT I
# PROLOGUE
#
#     Two households, both alike in dignity,
#     In fair Verona, where we lay our scene,
#     From ancient grudge break to new mutiny,
#     Where civil blood makes civil hands unclean.
#     From forth the fatal loins of these two foes
#     A pair of star-cross'd lovers take their life;
#     Whose misadventured piteous overthrows
#     Do with their death bury their parents' strife.
#     The fearful passage of their death-mark'd love,
#     And the continuance of their parents' rage,
#     Which, but their children's end, nought could remove,
#     Is now the two hours' traffic of our stage;
#     The which if you with patient ears attend,
#     What here shall miss, our toil shall strive to mend.
#
# SCENE I. Verona. A public place.
#
#     Enter SAMPSON and GREGORY, of the house of Capulet, armed with swords and bucklers
#
# SAMPSON
#
#     Gregory, o' my word, we'll not carry coals.
#
# GREGORY
#
# ...

# %%
infname = 'C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/RnJ.txt'
inf=open(infname,'r')
line=inf.readline()
for line in inf:
    print(line,end='')
inf.close()
# Out:
# Romeo and Juliet
#
# ACT I
# PROLOGUE
#
#     Two households, both alike in dignity,
#     In fair Verona, where we lay our scene,
#     From ancient grudge break to new mutiny,
#     Where civil blood makes civil hands unclean.
#     From forth the fatal loins of these two foes
#     A pair of star-cross'd lovers take their life;
#     Whose misadventured piteous overthrows
#     Do with their death bury their parents' strife.
#     The fearful passage of their death-mark'd love,
#     And the continuance of their parents' rage,
#     Which, but their children's end, nought could remove,
#     Is now the two hours' traffic of our stage;
#     The which if you with patient ears attend,
#     What here shall miss, our toil shall strive to mend.
#
# SCENE I. Verona. A public place.
#
#     Enter SAMPSON and GREGORY, of the house of Capulet, armed with swords and bucklers
#
# SAMPSON
#
#     Gregory, o' my word, we'll not carry coals.
#
# GREGORY
#
# ...

# %%
inf=open('conan.jpeg','rb')
byte=inf.read(1)
while byte:
    print(byte)
    byte=inf.read(1)
inf.close()
# Out:
# b'\xff'
# b'\xd8'
# b'\xff'
# b'\xe0'
# b'\x00'
# b'\x10'
# b'J'
# b'F'
# b'I'
# b'F'
# b'\x00'
# b'\x01'
# b'\x01'
# b'\x01'
# b'\x00'
# b'H'
# b'\x00'
# b'H'
# b'\x00'
# b'\x00'
# b'\xff'
# b'\xdb'
# b'\x00'
# b'C'
# b'\x00'
# b'\x08'
# b'\x06'
# b'\x06'
# b'\x07'
# b'\x06'
# b'\x05'
# b'\x08'
# b'\x07'
# b'\x07'
# b'\x07'
# b'\t'
# b'\t'
# b'\x08'
# b'\n'
# b'\x0c'
# b'\x14'
# b'\r'
# b'\x0c'
# b'\x0b'
# b'\x0b'
# b'\x0c'
# b'\x19'
# b'\x12'
# b'\x13'
# b'\x0f'
# b'\x14'
# b'\x1d'
# b'\x1a'
# b'\x1f'
# b'\x1e'
# b'\x1d'
# b'\x1a'
# b'\x1c'
# b'\x1c'
# b' '
# b'$'
# b'.'
# b"'"
# b' '
# b'"'
# b','
# b'#'
# b'\x1c'
# b'\x1c'
# b'('
# b'7'
# b')'
# b','
# b'0'
# b'1'
# b'4'
# b'4'
# b'4'
# b'\x1f'
# b"'"
# b'9'
# b'='
# b'8'
# b'2'
# b'<'
# b'.'
# b'3'
# b'4'
# b'2'
# b'\xff'
# b'\xdb'
# b'\x00'
# b'C'
# b'\x01'
# b'\t'
# b'\t'
# b'\t'
# b'\x0c'
# b'\x0b'
# b'\x0c'
# b'\x18'
# b'\r'
# b'\r'
# b'\x18'
# b'2'
# b'!'
# b'\x1c'
# b'!'
# b'2'
# b'2'
# b'2'
# b'2'
# b'2'
# b'2'
# b'2'
# ...

# %%
infname = 'C:/Users/user/Desktop/Python/Python基礎與物件導向概念介紹/RnJ.txt'
with open(infname,'r') as f:
    lines=f.readlines()
    for line in lines:
        print(line,end='')
# Out:
# Romeo and Juliet
#
# ACT I
# PROLOGUE
#
#     Two households, both alike in dignity,
#     In fair Verona, where we lay our scene,
#     From ancient grudge break to new mutiny,
#     Where civil blood makes civil hands unclean.
#     From forth the fatal loins of these two foes
#     A pair of star-cross'd lovers take their life;
#     Whose misadventured piteous overthrows
#     Do with their death bury their parents' strife.
#     The fearful passage of their death-mark'd love,
#     And the continuance of their parents' rage,
#     Which, but their children's end, nought could remove,
#     Is now the two hours' traffic of our stage;
#     The which if you with patient ears attend,
#     What here shall miss, our toil shall strive to mend.
#
# SCENE I. Verona. A public place.
#
#     Enter SAMPSON and GREGORY, of the house of Capulet, armed with swords and bucklers
#
# SAMPSON
#
#     Gregory, o' my word, we'll not carry coals.
#
# GREGORY
#
# ...

# %%
str1 = 'This is 中文'
print(len(str1))

bytes1 = b'\x80\xAB\x12\xFF'
print(len(bytes1))
# Out:
# 10
# 4

# %%
data = b'wxy\x7a'
print(data)
print(type(data))
print(data[0])
print(type(data[0]))
# Out:
# b'wxyz'
# <class 'bytes'>
# 119
# <class 'int'>

# %%
ba=bytearray(data)
print(type(ba),type(ba[0]))
ba[3]=0x70
print(ba)
# Out:
# <class 'bytearray'> <class 'int'>
# bytearray(b'wxyp')

# %%
str1 = '這是個abc測試'
bytes1 = str1.encode('utf-8')
print(bytes1)
bytes2 = str1.encode('big5')
print(bytes2)

str2 = bytes2.decode('big5')
print(str2)
str3 = bytes2.decode('gbk')
print(str3)
str4 = bytes2.decode('utf-8')
print(str4)
# Out:
# b'\xe9\x80\x99\xe6\x98\xaf\xe5\x80\x8babc\xe6\xb8\xac\xe8\xa9\xa6'
# b'\xb3o\xacO\xad\xd3abc\xb4\xfa\xb8\xd5'
# 這是個abc測試
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-98-b87f05fad7f6> in <module>
#       7 str2 = bytes2.decode('big5')
#       8 print(str2)
# ----> 9 str3 = bytes2.decode('gbk')
#      10 print(str3)
#      11 str4 = bytes2.decode('utf-8')
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0xad in position 4: illegal multibyte sequence

# %%
import sys
with open('stdout.txt','w',encoding='utf-8') as fout:
    backup=sys.stdout
    sys.stdout=fout
    print('哈哈')
    sys.stdout=backup
