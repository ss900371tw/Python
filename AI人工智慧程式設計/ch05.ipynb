# %%
def splitSequence(seq, steps):
    x = []
    y = []
    len1 = len(seq)
    for i in range(len1):
        end_ix = i+steps
        if end_ix>len1-1:
            break
        x.append(seq[i:end_ix])
        y.append(seq[end_ix])
    return x, y

#list1 = [10, 20, 30, 40, 50, 60, 70, 80, 90]
list1 = []
for i in range(100):
    list1.append((i+1)*10+5)

n_steps = 3
listX, listY = splitSequence(list1, n_steps)
for x, y in zip(listX, listY):
    print(x, y)
# Out:
# [15, 25, 35] 45
# [25, 35, 45] 55
# [35, 45, 55] 65
# [45, 55, 65] 75
# [55, 65, 75] 85
# [65, 75, 85] 95
# [75, 85, 95] 105
# [85, 95, 105] 115
# [95, 105, 115] 125
# [105, 115, 125] 135
# [115, 125, 135] 145
# [125, 135, 145] 155
# [135, 145, 155] 165
# [145, 155, 165] 175
# [155, 165, 175] 185
# [165, 175, 185] 195
# [175, 185, 195] 205
# [185, 195, 205] 215
# [195, 205, 215] 225
# [205, 215, 225] 235
# [215, 225, 235] 245
# [225, 235, 245] 255
# [235, 245, 255] 265
# [245, 255, 265] 275
# [255, 265, 275] 285
# [265, 275, 285] 295
# [275, 285, 295] 305
# [285, 295, 305] 315
# [295, 305, 315] 325
# [305, 315, 325] 335
# [315, 325, 335] 345
# [325, 335, 345] 355
# [335, 345, 355] 365
# [345, 355, 365] 375
# [355, 365, 375] 385
# [365, 375, 385] 395
# [375, 385, 395] 405
# [385, 395, 405] 415
# [395, 405, 415] 425
# [405, 415, 425] 435
# [415, 425, 435] 445
# [425, 435, 445] 455
# [435, 445, 455] 465
# [445, 455, 465] 475
# [455, 465, 475] 485
# [465, 475, 485] 495
# ...

# %%
import numpy as np

arrayX = np.array(listX)
arrayY = np.array(listY)
print(arrayX.shape)
print(arrayY.shape)

arrayX = arrayX.reshape(arrayX.shape[0], arrayX.shape[1], 1)
print(arrayX.shape)
# Out:
# (97, 3)
# (97,)
# (97, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

model = Sequential()

model.add(Conv1D(32, 2, activation='relu', input_shape=(arrayX.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(1))

print(model.summary())
model.compile(loss='mse', optimizer=Adam(lr=0.001))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d (Conv1D)              (None, 2, 32)             96
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1, 32)             0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# ...
# Total params: 641
# Trainable params: 641
# Non-trainable params: 0
# _________________________________________________________________
# None
# ...

# %%
import matplotlib.pyplot as plt

train_history = model.fit(arrayX, arrayY, epochs=1500)

plt.plot(train_history.history['loss'], label='Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')

plt.show()
# Out:
# Epoch 1/1500
# 4/4 [==============================] - 1s 5ms/step - loss: 313798.0312
# Epoch 2/1500
# 4/4 [==============================] - 0s 4ms/step - loss: 292695.9688
# Epoch 3/1500
# 4/4 [==============================] - 0s 4ms/step - loss: 272067.6562
# Epoch 4/1500
# 4/4 [==============================] - 0s 4ms/step - loss: 252821.8594
# Epoch 5/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 232227.9219
# Epoch 6/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 208977.4219
# Epoch 7/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 188080.9688
# Epoch 8/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 166688.8281
# Epoch 9/1500
# 4/4 [==============================] - 0s 9ms/step - loss: 146007.2500
# Epoch 10/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 127119.1641
# Epoch 11/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 109502.8828
# Epoch 12/1500
# ...

# %%
x_input = np.array([70, 80, 90])
x_input = x_input.reshape(1, 3, 1)
yhat = model.predict(x_input)
print(yhat)

x_input = np.array([5, 15, 25])
x_input = x_input.reshape(1, 3, 1)
yhat = model.predict(x_input)
print(yhat)

x_input = np.array([35, 45, 55])
x_input = x_input.reshape(1, 3, 1)
yhat = model.predict(x_input)
print(yhat)

x_input = np.array([58, 68, 78])
x_input = x_input.reshape(1, 3, 1)
yhat = model.predict(x_input)
print(yhat)

x_input = np.array([400, 500, 600])
x_input = x_input.reshape(1, 3, 1)
yhat = model.predict(x_input)
print(yhat)

x_input = np.array([40, 60, 80])
x_input = x_input.reshape(1, 3, 1)
yhat = model.predict(x_input)
print(yhat)

x_input = np.array([15, 20, 25])
x_input = x_input.reshape(1, 3, 1)
yhat = model.predict(x_input)
print(yhat)

x_input = np.array([5, 6, 7])
x_input = x_input.reshape(1, 3, 1)
yhat = model.predict(x_input)
print(yhat)
# Out:
# [[99.229645]]
# [[34.150047]]
# [[64.175285]]
# [[87.21101]]
# [[610.97845]]
# [[89.32041]]
# [[34.062107]]
# [[15.957623]]
